# %%
import pandas as pd
import pandasgui
import plotly.express as px
import numpy as np
pd.set_option('display.float_format', '{:.3f}'.format)

# %%
df_formulacao1 = pd.read_excel("SOLUTION/FINAL/2024 06 24 1f53d2b.xlsx", sheet_name='Sheet1', engine="openpyxl")

# %%
# df_formulacao1["setup_cost_end_products_perc"] = df_formulacao1["setup_cost_end_products"]/df_formulacao1["objective_function"]
# df_formulacao1["holding_cost_end_products_perc"] = df_formulacao1["holding_cost_end_products"]/df_formulacao1["objective_function"]
# df_formulacao1["end_products_cost_perc"] = df_formulacao1["end_products_cost"]/df_formulacao1["objective_function"]
# df_formulacao1["setup_cost_ingredients_perc"] = df_formulacao1["setup_cost_ingredients"]/df_formulacao1["objective_function"]
# df_formulacao1["production_cost_ingredients_perc"] = df_formulacao1["production_cost_ingredients"]/df_formulacao1["objective_function"]
# df_formulacao1["holding_cost_end_ingredients_perc"] = df_formulacao1["holding_cost_end_ingredients"]/df_formulacao1["objective_function"]
# df_formulacao1["ingredients_cost_perc"] = df_formulacao1["ingredients_cost"]/df_formulacao1["objective_function"]

# df_formulacao1["objective_function_without_ingredients"] = df_formulacao1["objective_function"] - df_formulacao1["production_cost_ingredients"]

# cols1 = ["setup_cost_end_products_perc", "holding_cost_end_products_perc", "setup_cost_ingredients_perc", "production_cost_ingredients_perc", "holding_cost_end_ingredients_perc"]

# df_formulacao1[cols1].describe()

# %%
# df_formulacao1["setup_cost_end_products_perc2"] = df_formulacao1["setup_cost_end_products"]/df_formulacao1["objective_function_without_ingredients"]
# df_formulacao1["holding_cost_end_products_perc2"] = df_formulacao1["holding_cost_end_products"]/df_formulacao1["objective_function_without_ingredients"]
# df_formulacao1["end_products_cost_perc2"] = df_formulacao1["end_products_cost"]/df_formulacao1["objective_function_without_ingredients"]
# df_formulacao1["setup_cost_ingredients_perc2"] = df_formulacao1["setup_cost_ingredients"]/df_formulacao1["objective_function_without_ingredients"]
# df_formulacao1["production_cost_ingredients_perc2"] = df_formulacao1["production_cost_ingredients"]/df_formulacao1["objective_function_without_ingredients"]
# df_formulacao1["holding_cost_end_ingredients_perc2"] = df_formulacao1["holding_cost_end_ingredients"]/df_formulacao1["objective_function_without_ingredients"]

# cols2 = ["setup_cost_end_products_perc2", "holding_cost_end_products_perc2", "setup_cost_ingredients_perc2", "holding_cost_end_ingredients_perc2"]

# df_formulacao1[cols2].describe()

# %%
# col_keys = ["capacity_multiplier", "coef_cap", "amount_of_end_products"]
# ingredient_cols = ["setup_cost_ingredients_perc2", "holding_cost_end_ingredients_perc2"]
# df_formulacao1[ingredient_cols + col_keys].groupby(by=col_keys).agg("mean")

# %%
# df_formulacao1.head()
# Out:
#       setup_cost_end_products  production_cost_end_products  \
# 2875                      NaN                           NaN
# 2876                    8e+06                             0
# 2877                      NaN                           NaN
# 2878                      NaN                           NaN
# 2879                      NaN                           NaN
#
#       holding_cost_end_products  end_products_cost  setup_cost_ingredients  \
# 2875                        NaN                NaN                     NaN
# 2876                    1.7e+05            8.2e+06                 8.5e+06
# 2877                        NaN                NaN                     NaN
# 2878                        NaN                NaN                     NaN
# 2879                        NaN                NaN                     NaN
#
#       production_cost_ingredients  holding_cost_end_ingredients  \
# 2875                          NaN                           NaN
# 2876                      8.2e+07                             0
# 2877                          NaN                           NaN
# 2878                          NaN                           NaN
# 2879                          NaN                           NaN
#
#       ingredients_cost  end_product_uc  ingredients_uc  ...  coef_cap  \
# 2875               NaN             NaN             NaN  ...         1
# 2876           9.1e+07             0.8            0.77  ...       1.3
# 2877               NaN             NaN             NaN  ...         1
# 2878               NaN             NaN             NaN  ...       1.3
# 2879               NaN             NaN             NaN  ...       1.3
#
#      type_cap_ingredients  ingredient_capacity amount_of_end_products  \
# 2875                    S                1e+02                      1
# 2876                    S              7.3e+02                      5
# 2877                    S              4.9e+02                      5
# 2878                    S              1.3e+02                      1
# 2879                    S              2.3e+02                      1
#
#           status Best Bound    Gap  Nodes Processed Tempo de Solução  \
# 2875  infeasible        NaN    NaN              NaN              NaN
# 2876      solved    9.9e+07 0.0001          2.8e+04          1.1e+02
# 2877  infeasible        NaN    NaN              NaN              NaN
# 2878  infeasible        NaN    NaN              NaN              NaN
# 2879  infeasible        NaN    NaN              NaN              NaN
#
#       Relaxed Objective Value
# 2875                      NaN
# 2876                  9.9e+07
# 2877                      NaN
# 2878                      NaN
# 2879                      NaN
#
# [5 rows x 24 columns]

# %%
# fig = px.histogram(data_frame=df_formulacao1, x=['ingredients_uc', 'end_product_uc'],
#     color=None, facet_row='type_cap_ingredients', facet_col=
#     'amount_of_end_products', marginal=None, cumulative=False, )

# fig.show()

# %%
# pandasgui.show(df_formulacao1)
# Out:
# PandasGUI INFO — pandasgui.gui — Opening PandasGUI

# %%
col_keys2 = ['Instance', 'capacity_multiplier', 'type_cap_ingredients', 'coef_cap', 'amount_of_end_products']
col_keys3 = ['capacity_multiplier', 'coef_cap', 'amount_of_end_products']

# %%
# pandasgui.show(df_formulacao1.set_index(col_keys2)[['ingredients_uc', 'end_product_uc']].sort_index().reset_index())

# %%
# pandasgui.show(df_formulacao1.set_index(col_keys2).sort_index().reset_index().iloc[[8732,8733,8734]])

# %%
pd.pivot_table(df_formulacao1, index=col_keys3, aggfunc={'ingredients_uc': np.mean, 'end_product_uc': np.mean}).reset_index().rename(columns={'capacity_multiplier': 'capacidade produtos finais', 'coef_cap': 'multiplicador cap ingredients'})
# Out:
#    capacidade produtos finais  multiplicador cap ingredients  \
# 0                           L                          1.030
# 1                           L                          1.030
# 2                           L                          1.030
# 3                           L                          1.050
# 4                           L                          1.050
# 5                           L                          1.050
# 6                           L                          1.100
# 7                           L                          1.100
# 8                           L                          1.100
# 9                           L                          1.300
# 10                          L                          1.300
# 11                          L                          1.300
# 12                          L                          1.400
# 13                          L                          1.400
# 14                          L                          1.400
# 15                          L                          1.700
# 16                          L                          1.700
# 17                          L                          1.700
# 18                          N                          1.030
# 19                          N                          1.030
# 20                          N                          1.030
# 21                          N                          1.050
# 22                          N                          1.050
# 23                          N                          1.050
# 24                          N                          1.100
# 25                          N                          1.100
# 26                          N                          1.100
# 27                          N                          1.300
# 28                          N                          1.300
# 29                          N                          1.300
# 30                          N                          1.400
# 31                          N                          1.400
# 32                          N                          1.400
# 33                          N                          1.700
# 34                          N                          1.700
# 35                          N                          1.700
#
#     amount_of_end_products  end_product_uc  ingredients_uc
# 0                        1           0.766           0.971
# 1                        5           0.766           0.971
# 2                       10           0.766           0.971
# 3                        1           0.768           0.952
# 4                        5           0.767           0.952
# 5                       10           0.767           0.952
# 6                        1           0.766           0.909
# 7                        5           0.766           0.909
# 8                       10           0.766           0.909
# 9                        1           0.769           0.769
# 10                       5           0.769           0.769
# 11                      10           0.769           0.769
# 12                       1           0.769           0.714
# 13                       5           0.769           0.714
# 14                      10           0.769           0.714
# 15                       1           0.769           0.588
# 16                       5           0.769           0.588
# 17                      10           0.769           0.588
# 18                       1           0.498           0.971
# 19                       5           0.497           0.971
# 20                      10           0.497           0.971
# 21                       1           0.499           0.952
# 22                       5           0.497           0.952
# 23                      10           0.497           0.952
# 24                       1           0.497           0.909
# 25                       5           0.496           0.909
# 26                      10           0.496           0.909
# 27                       1           0.498           0.769
# 28                       5           0.498           0.769
# 29                      10           0.498           0.769
# 30                       1           0.499           0.714
# 31                       5           0.498           0.714
# 32                      10           0.498           0.714
# 33                       1           0.498           0.588
# 34                       5           0.498           0.588
# 35                      10           0.498           0.588

# %%
pd.pivot_table(df_formulacao1, index=col_keys3, columns=['status'], aggfunc={'status': 'count', 'Gap': np.mean}).reset_index().rename(columns={'capacity_multiplier': 'capacidade produtos finais', 'coef_cap': 'multiplicador cap ingredients'})
# Out:
#        capacidade produtos finais multiplicador cap ingredients  \
# status
# 0                               L                         1.000
# 1                               L                         1.000
# 2                               L                         1.000
# 3                               L                         1.005
# 4                               L                         1.005
# 5                               L                         1.005
# 6                               L                         1.030
# 7                               L                         1.030
# 8                               L                         1.030
# 9                               L                         1.050
# 10                              L                         1.050
# 11                              L                         1.050
# 12                              L                         1.100
# 13                              L                         1.100
# 14                              L                         1.100
# 15                              L                         1.300
# 16                              L                         1.300
# 17                              L                         1.300
# 18                              L                         1.400
# 19                              L                         1.400
# 20                              L                         1.400
# 21                              L                         1.700
# 22                              L                         1.700
# 23                              L                         1.700
# 24                              N                         1.000
# 25                              N                         1.000
# 26                              N                         1.000
# 27                              N                         1.005
# 28                              N                         1.005
# 29                              N                         1.005
# 30                              N                         1.030
# 31                              N                         1.030
# 32                              N                         1.030
# 33                              N                         1.050
# 34                              N                         1.050
# 35                              N                         1.050
# 36                              N                         1.100
# 37                              N                         1.100
# 38                              N                         1.100
# 39                              N                         1.300
# 40                              N                         1.300
# 41                              N                         1.300
# 42                              N                         1.400
# 43                              N                         1.400
# 44                              N                         1.400
# 45                              N                         1.700
# 46                              N                         1.700
# 47                              N                         1.700
#
#        amount_of_end_products    Gap     status
# status                        solved infeasible solved
# 0                           1    NaN     60.000    NaN
# 1                           5    NaN     60.000    NaN
# 2                          10    NaN     60.000    NaN
# 3                           1    NaN     60.000    NaN
# 4                           5    NaN     60.000    NaN
# 5                          10    NaN     60.000    NaN
# 6                           1  0.000     56.000  4.000
# 7                           5  0.001     56.000  4.000
# 8                          10  0.001     56.000  4.000
# 9                           1  0.000     46.000 14.000
# 10                          5  0.000     46.000 14.000
# 11                         10  0.001     46.000 14.000
# 12                          1  0.000     40.000 20.000
# 13                          5  0.001     40.000 20.000
# 14                         10  0.001     40.000 20.000
# 15                          1  0.000     14.000 46.000
# 16                          5  0.001     14.000 46.000
# 17                         10  0.001     14.000 46.000
# 18                          1  0.000     14.000 46.000
# 19                          5  0.001     14.000 46.000
# 20                         10  0.001     14.000 46.000
# 21                          1  0.000     14.000 46.000
# 22                          5  0.001     14.000 46.000
# 23                         10  0.001     14.000 46.000
# 24                          1    NaN     60.000    NaN
# 25                          5    NaN     60.000    NaN
# 26                         10    NaN     60.000    NaN
# 27                          1    NaN     60.000    NaN
# 28                          5    NaN     60.000    NaN
# 29                         10    NaN     60.000    NaN
# 30                          1  0.000     56.000  4.000
# 31                          5  0.002     56.000  4.000
# 32                         10  0.002     56.000  4.000
# 33                          1  0.000     46.000 14.000
# 34                          5  0.002     46.000 14.000
# 35                         10  0.001     46.000 14.000
# 36                          1  0.000     40.000 20.000
# 37                          5  0.001     40.000 20.000
# 38                         10  0.002     40.000 20.000
# 39                          1  0.000     14.000 46.000
# 40                          5  0.002     14.000 46.000
# 41                         10  0.002     14.000 46.000
# 42                          1  0.000      6.000 54.000
# 43                          5  0.002      6.000 54.000
# 44                         10  0.002      6.000 54.000
# 45                          1  0.000        NaN 60.000
# 46                          5  0.002        NaN 60.000
# 47                         10  0.002        NaN 60.000

# %%
pd.pivot_table(df_formulacao1, index=col_keys3, aggfunc={'Gap': np.mean}).reset_index().rename(columns={'capacity_multiplier': 'capacidade produtos finais', 'coef_cap': 'multiplicador cap ingredients'})
# Out:
#    capacidade produtos finais  multiplicador cap ingredients  \
# 0                           L                          1.030
# 1                           L                          1.030
# 2                           L                          1.030
# 3                           L                          1.050
# 4                           L                          1.050
# 5                           L                          1.050
# 6                           L                          1.100
# 7                           L                          1.100
# 8                           L                          1.100
# 9                           L                          1.300
# 10                          L                          1.300
# 11                          L                          1.300
# 12                          L                          1.400
# 13                          L                          1.400
# 14                          L                          1.400
# 15                          L                          1.700
# 16                          L                          1.700
# 17                          L                          1.700
# 18                          N                          1.030
# 19                          N                          1.030
# 20                          N                          1.030
# 21                          N                          1.050
# 22                          N                          1.050
# 23                          N                          1.050
# 24                          N                          1.100
# 25                          N                          1.100
# 26                          N                          1.100
# 27                          N                          1.300
# 28                          N                          1.300
# 29                          N                          1.300
# 30                          N                          1.400
# 31                          N                          1.400
# 32                          N                          1.400
# 33                          N                          1.700
# 34                          N                          1.700
# 35                          N                          1.700
#
#     amount_of_end_products   Gap
# 0                        1 0.000
# 1                        5 0.001
# 2                       10 0.001
# 3                        1 0.000
# 4                        5 0.000
# 5                       10 0.001
# 6                        1 0.000
# 7                        5 0.001
# 8                       10 0.001
# 9                        1 0.000
# 10                       5 0.001
# 11                      10 0.001
# 12                       1 0.000
# 13                       5 0.001
# 14                      10 0.001
# 15                       1 0.000
# 16                       5 0.001
# 17                      10 0.001
# 18                       1 0.000
# 19                       5 0.002
# 20                      10 0.002
# 21                       1 0.000
# 22                       5 0.002
# 23                      10 0.001
# 24                       1 0.000
# 25                       5 0.001
# 26                      10 0.002
# 27                       1 0.000
# 28                       5 0.002
# 29                      10 0.002
# 30                       1 0.000
# 31                       5 0.002
# 32                      10 0.002
# 33                       1 0.000
# 34                       5 0.002
# 35                      10 0.002
