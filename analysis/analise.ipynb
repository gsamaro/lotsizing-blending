# %%
import pandas as pd
import pandasgui
import plotly.express as px
import numpy as np
pd.set_option('display.float_format', '{:.3f}'.format)

# %%
df_formulacao1 = pd.read_excel("SOLUTION/FINAL/2024 06 25 0e1b138.xlsx", sheet_name='Sheet1', engine="openpyxl")

# %%
# df_formulacao1["setup_cost_end_products_perc"] = df_formulacao1["setup_cost_end_products"]/df_formulacao1["objective_function"]
# df_formulacao1["holding_cost_end_products_perc"] = df_formulacao1["holding_cost_end_products"]/df_formulacao1["objective_function"]
# df_formulacao1["end_products_cost_perc"] = df_formulacao1["end_products_cost"]/df_formulacao1["objective_function"]
# df_formulacao1["setup_cost_ingredients_perc"] = df_formulacao1["setup_cost_ingredients"]/df_formulacao1["objective_function"]
# df_formulacao1["production_cost_ingredients_perc"] = df_formulacao1["production_cost_ingredients"]/df_formulacao1["objective_function"]
# df_formulacao1["holding_cost_end_ingredients_perc"] = df_formulacao1["holding_cost_end_ingredients"]/df_formulacao1["objective_function"]
# df_formulacao1["ingredients_cost_perc"] = df_formulacao1["ingredients_cost"]/df_formulacao1["objective_function"]

# df_formulacao1["objective_function_without_ingredients"] = df_formulacao1["objective_function"] - df_formulacao1["production_cost_ingredients"]

# cols1 = ["setup_cost_end_products_perc", "holding_cost_end_products_perc", "setup_cost_ingredients_perc", "production_cost_ingredients_perc", "holding_cost_end_ingredients_perc"]

# df_formulacao1[cols1].describe()

# %%
# df_formulacao1["setup_cost_end_products_perc2"] = df_formulacao1["setup_cost_end_products"]/df_formulacao1["objective_function_without_ingredients"]
# df_formulacao1["holding_cost_end_products_perc2"] = df_formulacao1["holding_cost_end_products"]/df_formulacao1["objective_function_without_ingredients"]
# df_formulacao1["end_products_cost_perc2"] = df_formulacao1["end_products_cost"]/df_formulacao1["objective_function_without_ingredients"]
# df_formulacao1["setup_cost_ingredients_perc2"] = df_formulacao1["setup_cost_ingredients"]/df_formulacao1["objective_function_without_ingredients"]
# df_formulacao1["production_cost_ingredients_perc2"] = df_formulacao1["production_cost_ingredients"]/df_formulacao1["objective_function_without_ingredients"]
# df_formulacao1["holding_cost_end_ingredients_perc2"] = df_formulacao1["holding_cost_end_ingredients"]/df_formulacao1["objective_function_without_ingredients"]

# cols2 = ["setup_cost_end_products_perc2", "holding_cost_end_products_perc2", "setup_cost_ingredients_perc2", "holding_cost_end_ingredients_perc2"]

# df_formulacao1[cols2].describe()

# %%
# col_keys = ["capacity_multiplier", "coef_cap", "amount_of_end_products"]
# ingredient_cols = ["setup_cost_ingredients_perc2", "holding_cost_end_ingredients_perc2"]
# df_formulacao1[ingredient_cols + col_keys].groupby(by=col_keys).agg("mean")

# %%
# df_formulacao1.head()

# %%
# fig = px.histogram(data_frame=df_formulacao1, x=['ingredients_uc', 'end_product_uc'],
#     color=None, facet_row='type_cap_ingredients', facet_col=
#     'amount_of_end_products', marginal=None, cumulative=False, )

# fig.show()

# %%
# pandasgui.show(df_formulacao1)

# %%
col_keys2 = ['Instance', 'capacity_multiplier', 'type_cap_ingredients', 'coef_cap', 'amount_of_end_products']
col_keys3 = ['capacity_multiplier', 'coef_cap', 'amount_of_end_products']

# %%
# pandasgui.show(df_formulacao1.set_index(col_keys2)[['ingredients_uc', 'end_product_uc']].sort_index().reset_index())

# %%
# pandasgui.show(df_formulacao1.set_index(col_keys2).sort_index().reset_index().iloc[[8732,8733,8734]])

# %%
pd.pivot_table(df_formulacao1, index=col_keys3, aggfunc={'ingredients_uc': np.mean, 'end_product_uc': np.mean}).reset_index().rename(columns={'capacity_multiplier': 'capacidade produtos finais', 'coef_cap': 'multiplicador cap ingredients'})
# Out:
#    capacidade produtos finais  multiplicador cap ingredients  \
# 0                           L                          1.000
# 1                           L                          1.000
# 2                           L                          1.000
# 3                           L                          1.005
# 4                           L                          1.005
# 5                           L                          1.005
# 6                           L                          1.030
# 7                           L                          1.030
# 8                           L                          1.030
# 9                           L                          1.050
# 10                          L                          1.050
# 11                          L                          1.050
# 12                          L                          1.100
# 13                          L                          1.100
# 14                          L                          1.100
# 15                          L                          1.300
# 16                          L                          1.300
# 17                          L                          1.300
# 18                          L                          1.400
# 19                          L                          1.400
# 20                          L                          1.400
# 21                          L                          1.700
# 22                          L                          1.700
# 23                          L                          1.700
# 24                          N                          1.000
# 25                          N                          1.000
# 26                          N                          1.000
# 27                          N                          1.005
# 28                          N                          1.005
# 29                          N                          1.005
# 30                          N                          1.030
# 31                          N                          1.030
# 32                          N                          1.030
# 33                          N                          1.050
# 34                          N                          1.050
# 35                          N                          1.050
# 36                          N                          1.100
# 37                          N                          1.100
# 38                          N                          1.100
# 39                          N                          1.300
# 40                          N                          1.300
# 41                          N                          1.300
# 42                          N                          1.400
# 43                          N                          1.400
# 44                          N                          1.400
# 45                          N                          1.700
# 46                          N                          1.700
# 47                          N                          1.700
#
#     amount_of_end_products  end_product_uc  ingredients_uc
# 0                        1           0.671           0.871
# 1                        5           0.697           0.906
# 2                       10           0.699           0.908
# 3                        1           0.674           0.870
# 4                        5           0.699           0.903
# 5                       10           0.701           0.907
# 6                        1           0.681           0.857
# 7                        5           0.703           0.887
# 8                       10           0.708           0.893
# 9                        1           0.679           0.839
# 10                       5           0.703           0.870
# 11                      10           0.705           0.872
# 12                       1           0.680           0.803
# 13                       5           0.703           0.831
# 14                      10           0.706           0.834
# 15                       1           0.685           0.685
# 16                       5           0.704           0.704
# 17                      10           0.707           0.707
# 18                       1           0.687           0.637
# 19                       5           0.705           0.655
# 20                      10           0.707           0.656
# 21                       1           0.691           0.529
# 22                       5           0.705           0.539
# 23                      10           0.706           0.540
# 24                       1           0.436           0.870
# 25                       5           0.453           0.907
# 26                      10           0.454           0.909
# 27                       1           0.438           0.869
# 28                       5           0.454           0.905
# 29                      10           0.455           0.908
# 30                       1           0.442           0.858
# 31                       5           0.458           0.891
# 32                      10           0.459           0.893
# 33                       1           0.442           0.841
# 34                       5           0.457           0.872
# 35                      10           0.459           0.876
# 36                       1           0.442           0.805
# 37                       5           0.457           0.833
# 38                      10           0.459           0.837
# 39                       1           0.444           0.685
# 40                       5           0.457           0.706
# 41                      10           0.459           0.708
# 42                       1           0.447           0.640
# 43                       5           0.458           0.656
# 44                      10           0.459           0.658
# 45                       1           0.449           0.530
# 46                       5           0.457           0.539
# 47                      10           0.459           0.541

# %%
pd.pivot_table(df_formulacao1, index=col_keys3, columns=['status'], aggfunc={'status': 'count', 'Gap': np.mean}).reset_index().rename(columns={'capacity_multiplier': 'capacidade produtos finais', 'coef_cap': 'multiplicador cap ingredients'})
# Out:
#        capacidade produtos finais multiplicador cap ingredients  \
# status
# 0                               L                         1.000
# 1                               L                         1.000
# 2                               L                         1.000
# 3                               L                         1.005
# 4                               L                         1.005
# 5                               L                         1.005
# 6                               L                         1.030
# 7                               L                         1.030
# 8                               L                         1.030
# 9                               L                         1.050
# 10                              L                         1.050
# 11                              L                         1.050
# 12                              L                         1.100
# 13                              L                         1.100
# 14                              L                         1.100
# 15                              L                         1.300
# 16                              L                         1.300
# 17                              L                         1.300
# 18                              L                         1.400
# 19                              L                         1.400
# 20                              L                         1.400
# 21                              L                         1.700
# 22                              L                         1.700
# 23                              L                         1.700
# 24                              N                         1.000
# 25                              N                         1.000
# 26                              N                         1.000
# 27                              N                         1.005
# 28                              N                         1.005
# 29                              N                         1.005
# 30                              N                         1.030
# 31                              N                         1.030
# 32                              N                         1.030
# 33                              N                         1.050
# 34                              N                         1.050
# 35                              N                         1.050
# 36                              N                         1.100
# 37                              N                         1.100
# 38                              N                         1.100
# 39                              N                         1.300
# 40                              N                         1.300
# 41                              N                         1.300
# 42                              N                         1.400
# 43                              N                         1.400
# 44                              N                         1.400
# 45                              N                         1.700
# 46                              N                         1.700
# 47                              N                         1.700
#
#        amount_of_end_products    Gap status
# status                        solved solved
# 0                           1  0.000     60
# 1                           5  0.000     60
# 2                          10  0.000     60
# 3                           1  0.000     60
# 4                           5  0.000     60
# 5                          10  0.000     60
# 6                           1  0.000     60
# 7                           5  0.000     60
# 8                          10  0.001     60
# 9                           1  0.000     60
# 10                          5  0.000     60
# 11                         10  0.001     60
# 12                          1  0.000     60
# 13                          5  0.001     60
# 14                         10  0.001     60
# 15                          1  0.001     60
# 16                          5  0.001     60
# 17                         10  0.001     60
# 18                          1  0.001     60
# 19                          5  0.001     60
# 20                         10  0.001     60
# 21                          1  0.001     60
# 22                          5  0.001     60
# 23                         10  0.001     60
# 24                          1  0.000     60
# 25                          5  0.001     60
# 26                         10  0.001     60
# 27                          1  0.000     60
# 28                          5  0.001     60
# 29                         10  0.001     60
# 30                          1  0.000     60
# 31                          5  0.001     60
# 32                         10  0.001     60
# 33                          1  0.000     60
# 34                          5  0.001     60
# 35                         10  0.001     60
# 36                          1  0.000     60
# 37                          5  0.002     60
# 38                         10  0.002     60
# 39                          1  0.001     60
# 40                          5  0.002     60
# 41                         10  0.002     60
# 42                          1  0.001     60
# 43                          5  0.002     60
# 44                         10  0.002     60
# 45                          1  0.001     60
# 46                          5  0.002     60
# 47                         10  0.002     60

# %%
pd.pivot_table(df_formulacao1, index=col_keys3, aggfunc={'Gap': np.mean}).reset_index().rename(columns={'capacity_multiplier': 'capacidade produtos finais', 'coef_cap': 'multiplicador cap ingredients'})
# Out:
#    capacidade produtos finais  multiplicador cap ingredients  \
# 0                           L                          1.000
# 1                           L                          1.000
# 2                           L                          1.000
# 3                           L                          1.005
# 4                           L                          1.005
# 5                           L                          1.005
# 6                           L                          1.030
# 7                           L                          1.030
# 8                           L                          1.030
# 9                           L                          1.050
# 10                          L                          1.050
# 11                          L                          1.050
# 12                          L                          1.100
# 13                          L                          1.100
# 14                          L                          1.100
# 15                          L                          1.300
# 16                          L                          1.300
# 17                          L                          1.300
# 18                          L                          1.400
# 19                          L                          1.400
# 20                          L                          1.400
# 21                          L                          1.700
# 22                          L                          1.700
# 23                          L                          1.700
# 24                          N                          1.000
# 25                          N                          1.000
# 26                          N                          1.000
# 27                          N                          1.005
# 28                          N                          1.005
# 29                          N                          1.005
# 30                          N                          1.030
# 31                          N                          1.030
# 32                          N                          1.030
# 33                          N                          1.050
# 34                          N                          1.050
# 35                          N                          1.050
# 36                          N                          1.100
# 37                          N                          1.100
# 38                          N                          1.100
# 39                          N                          1.300
# 40                          N                          1.300
# 41                          N                          1.300
# 42                          N                          1.400
# 43                          N                          1.400
# 44                          N                          1.400
# 45                          N                          1.700
# 46                          N                          1.700
# 47                          N                          1.700
#
#     amount_of_end_products   Gap
# 0                        1 0.000
# 1                        5 0.000
# 2                       10 0.000
# 3                        1 0.000
# 4                        5 0.000
# 5                       10 0.000
# 6                        1 0.000
# 7                        5 0.000
# 8                       10 0.001
# 9                        1 0.000
# 10                       5 0.000
# 11                      10 0.001
# 12                       1 0.000
# 13                       5 0.001
# 14                      10 0.001
# 15                       1 0.001
# 16                       5 0.001
# 17                      10 0.001
# 18                       1 0.001
# 19                       5 0.001
# 20                      10 0.001
# 21                       1 0.001
# 22                       5 0.001
# 23                      10 0.001
# 24                       1 0.000
# 25                       5 0.001
# 26                      10 0.001
# 27                       1 0.000
# 28                       5 0.001
# 29                      10 0.001
# 30                       1 0.000
# 31                       5 0.001
# 32                      10 0.001
# 33                       1 0.000
# 34                       5 0.001
# 35                      10 0.001
# 36                       1 0.000
# 37                       5 0.002
# 38                      10 0.002
# 39                       1 0.001
# 40                       5 0.002
# 41                      10 0.002
# 42                       1 0.001
# 43                       5 0.002
# 44                      10 0.002
# 45                       1 0.001
# 46                       5 0.002
# 47                      10 0.002
